# %% [markdown]
# **Repo Github** : https://github.com/MohammadSobri14/search-engine-smartfindr.git

# %% [markdown]
# **Tech Stack :**
#
# 🧠 1. Data Science & NLP
# Digunakan untuk pemrosesan data, ekstraksi fitur, dan pembobotan semantik.
#
# - Python – Bahasa utama yang digunakan untuk seluruh proses backend dan analisis data.
#
# - Jupyter Notebook – Untuk eksplorasi data, preprocessing, dan eksperimen model awal.
#
# - Pandas – Mengelola dan memanipulasi data tabular (CSV & hasil query SQL).
#
# - NumPy – Operasi numerik dan pengganti nilai NaN.
#
# - Torch (PyTorch) – Backend library dari SentenceTransformer untuk pemrosesan vektor NLP.
#
# - SentenceTransformer – Untuk mengubah teks menjadi vektor embedding (menggunakan model all-MiniLM-L6-v2).
#
# - scikit-learn (sklearn.metrics.pairwise.cosine_similarity) – Menghitung kemiripan antara vektor teks.
#
# 🕸️ 2. Web Scraping (untuk pengambilan data smartphone dari situs)
# - requests – Untuk mengambil konten HTML dari website.
#
# - BeautifulSoup – Untuk parsing dan ekstraksi data dari HTML.
#
# - re (Regular Expression) – Untuk ekstraksi informasi seperti "RAM 8GB", "kamera 50MP", dan "baterai 5000".
#
# 🛢️ 3. Database & ORM
# - MySQL – Tempat penyimpanan data smartphone.
#
# - mysql-connector-python – Untuk koneksi langsung ke database MySQL.
#
# - SQLAlchemy – ORM (Object Relational Mapper) untuk integrasi Python dan MySQL secara lebih fleksibel.
#
# 🌐 4. Web Framework (Backend)
# - Flask – Framework utama untuk membuat REST API dan menyajikan tampilan web.
#
# - Flask Templates (Jinja2) – Untuk merender halaman HTML dengan data dinamis.
#
# 🎨 5. Frontend & UI
# - Tailwind CSS – Framework CSS utility-first untuk membuat tampilan website yang modern dan responsif.
#
# - JavaScript DOM + Fetch API – Untuk fitur auto-suggestion dan interaktivitas di halaman pencarian.

# %%
import re
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# # **Scrapping**

# %% [markdown]
# Kode ini bertujuan untuk mengambil data halaman web dari situs Pricebook menggunakan metode HTTP GET.

# %%
url = "https://www.pricebook.co.id/smartphone/"
req = requests.get(url)

# %% [markdown]
# Fungsi ini digunakan untuk melakukan web scraping produk smartphone dari situs Pricebook secara otomatis dan berulang berdasarkan jumlah halaman yang ditentukan.
#
# Fungsi menerima dua parameter:
#
# - url: URL dasar dari halaman yang ingin di-scrape.
#
# - num_pages: jumlah halaman yang akan diambil datanya.
#
# Semua hasil dari scraping beberapa halaman akan digabung dan dikembalikan dalam bentuk list of dictionaries, siap untuk diproses lebih lanjut atau disimpan ke dalam file/dataset.

# %%
def crawl_products(url, num_pages):
    results = []

    for page in range(1, num_pages + 1):
        api_url = f"{url}?page={page}"
        print(f"Scraping: {api_url}")
        req = requests.get(api_url, headers={'User-Agent': 'Mozilla/5.0'})
        soup = BeautifulSoup(req.text, 'lxml')

        product_cards = soup.find_all('div', {'class': 'styles_productPanel__Tlvp6 row'})

        for idx, product in enumerate(product_cards):
            product_dict = {}
            ranking = product.find('span', {'class': "styles_productRanking__bYl4W"})
            name = product.find('h2', {'class': 'styles_productName__fr99s'})
            price = product.find('span', {'class': 'styles_price__nEARt'})
            year = product.find('div', {'class': 'styles_yearReleased___jyCv'})

            link = product.find('a', {'class': 'styles_linkReplace__oS0Gg'})
            product_url = url + link['href'] if link and 'href' in link.attrs else "N/A"

            product_image = product.find('div', {'class': 'styles_productImageWrapper__IwCKz'})
            product_tag = product_image.find('img') if product_image else None
            product_image_url = product_tag.get('src', 'N/A') if product_tag else "N/A"

            specs = product.find_all('div', {'class': 'gx-xs-0 ps-md-2 pe-md-3 d-inline-flex col-md-6 col-6'})
            ram = specs[0].find_all('span')[0].text.strip() if len(specs) > 0 else "N/A"
            camera = specs[1].find_all('span')[0].text.strip() if len(specs) > 1 else "N/A"
            screen = specs[2].find_all('span')[0].text.strip() if len(specs) > 2 else "N/A"
            battery = specs[3].find_all('span')[0].text.strip() if len(specs) > 3 else "N/A"

            # Change 'i' to 'page' to match the loop variable
            product_dict['ID'] = (page - 1) * len(product_cards) + idx + 1
            product_dict['Product Name'] = name.text.strip() if name else "N/A"
            product_dict['Product Rank'] = ranking.text.strip() if ranking else "N/A"
            product_dict['Ram'] = ram
            product_dict['Camera'] = camera
            product_dict['Screen'] = screen
            product_dict['Battery'] = battery
            product_dict['Price'] = price.text.strip() if price else "N/A"
            product_dict['Year'] = year.find_all('span')[0].text.strip() if year else "N/A"
            product_dict['Product URL'] = product_url
            product_dict['Product Image'] = product_image_url

            results.append(product_dict)

    return results

# %% [markdown]
# Melakukan scraping terhadap 500 halaman dari situs tersebut.

# %%
url = "https://www.pricebook.co.id/smartphone/"
crwl = crawl_products(url,500)
# Out:
# Scraping: https://www.pricebook.co.id/smartphone/?page=1
# Scraping: https://www.pricebook.co.id/smartphone/?page=2
# Scraping: https://www.pricebook.co.id/smartphone/?page=3
# Scraping: https://www.pricebook.co.id/smartphone/?page=4
# Scraping: https://www.pricebook.co.id/smartphone/?page=5
# Scraping: https://www.pricebook.co.id/smartphone/?page=6
# Scraping: https://www.pricebook.co.id/smartphone/?page=7
# Scraping: https://www.pricebook.co.id/smartphone/?page=8
# Scraping: https://www.pricebook.co.id/smartphone/?page=9
# Scraping: https://www.pricebook.co.id/smartphone/?page=10
# Scraping: https://www.pricebook.co.id/smartphone/?page=11
# Scraping: https://www.pricebook.co.id/smartphone/?page=12
# Scraping: https://www.pricebook.co.id/smartphone/?page=13
# Scraping: https://www.pricebook.co.id/smartphone/?page=14
# Scraping: https://www.pricebook.co.id/smartphone/?page=15
# Scraping: https://www.pricebook.co.id/smartphone/?page=16
# Scraping: https://www.pricebook.co.id/smartphone/?page=17
# Scraping: https://www.pricebook.co.id/smartphone/?page=18
# Scraping: https://www.pricebook.co.id/smartphone/?page=19
# Scraping: https://www.pricebook.co.id/smartphone/?page=20
# Scraping: https://www.pricebook.co.id/smartphone/?page=21
# Scraping: https://www.pricebook.co.id/smartphone/?page=22
# Scraping: https://www.pricebook.co.id/smartphone/?page=23
# Scraping: https://www.pricebook.co.id/smartphone/?page=24
# Scraping: https://www.pricebook.co.id/smartphone/?page=25
# Scraping: https://www.pricebook.co.id/smartphone/?page=26
# Scraping: https://www.pricebook.co.id/smartphone/?page=27
# Scraping: https://www.pricebook.co.id/smartphone/?page=28
# Scraping: https://www.pricebook.co.id/smartphone/?page=29
# Scraping: https://www.pricebook.co.id/smartphone/?page=30
# Scraping: https://www.pricebook.co.id/smartphone/?page=31
# Scraping: https://www.pricebook.co.id/smartphone/?page=32
# Scraping: https://www.pricebook.co.id/smartphone/?page=33
# Scraping: https://www.pricebook.co.id/smartphone/?page=34
# Scraping: https://www.pricebook.co.id/smartphone/?page=35
# Scraping: https://www.pricebook.co.id/smartphone/?page=36
# Scraping: https://www.pricebook.co.id/smartphone/?page=37
# Scraping: https://www.pricebook.co.id/smartphone/?page=38
# Scraping: https://www.pricebook.co.id/smartphone/?page=39
# Scraping: https://www.pricebook.co.id/smartphone/?page=40
# Scraping: https://www.pricebook.co.id/smartphone/?page=41
# Scraping: https://www.pricebook.co.id/smartphone/?page=42
# Scraping: https://www.pricebook.co.id/smartphone/?page=43
# Scraping: https://www.pricebook.co.id/smartphone/?page=44
# Scraping: https://www.pricebook.co.id/smartphone/?page=45
# Scraping: https://www.pricebook.co.id/smartphone/?page=46
# Scraping: https://www.pricebook.co.id/smartphone/?page=47
# Scraping: https://www.pricebook.co.id/smartphone/?page=48
# Scraping: https://www.pricebook.co.id/smartphone/?page=49
# Scraping: https://www.pricebook.co.id/smartphone/?page=50
# Scraping: https://www.pricebook.co.id/smartphone/?page=51
# Scraping: https://www.pricebook.co.id/smartphone/?page=52
# Scraping: https://www.pricebook.co.id/smartphone/?page=53
# Scraping: https://www.pricebook.co.id/smartphone/?page=54
# Scraping: https://www.pricebook.co.id/smartphone/?page=55
# Scraping: https://www.pricebook.co.id/smartphone/?page=56
# Scraping: https://www.pricebook.co.id/smartphone/?page=57
# Scraping: https://www.pricebook.co.id/smartphone/?page=58
# Scraping: https://www.pricebook.co.id/smartphone/?page=59
# Scraping: https://www.pricebook.co.id/smartphone/?page=60
# Scraping: https://www.pricebook.co.id/smartphone/?page=61
# Scraping: https://www.pricebook.co.id/smartphone/?page=62
# Scraping: https://www.pricebook.co.id/smartphone/?page=63
# Scraping: https://www.pricebook.co.id/smartphone/?page=64
# Scraping: https://www.pricebook.co.id/smartphone/?page=65
# Scraping: https://www.pricebook.co.id/smartphone/?page=66
# Scraping: https://www.pricebook.co.id/smartphone/?page=67
# Scraping: https://www.pricebook.co.id/smartphone/?page=68
# Scraping: https://www.pricebook.co.id/smartphone/?page=69
# Scraping: https://www.pricebook.co.id/smartphone/?page=70
# Scraping: https://www.pricebook.co.id/smartphone/?page=71
# Scraping: https://www.pricebook.co.id/smartphone/?page=72
# Scraping: https://www.pricebook.co.id/smartphone/?page=73
# Scraping: https://www.pricebook.co.id/smartphone/?page=74
# Scraping: https://www.pricebook.co.id/smartphone/?page=75
# Scraping: https://www.pricebook.co.id/smartphone/?page=76
# Scraping: https://www.pricebook.co.id/smartphone/?page=77
# Scraping: https://www.pricebook.co.id/smartphone/?page=78
# Scraping: https://www.pricebook.co.id/smartphone/?page=79
# Scraping: https://www.pricebook.co.id/smartphone/?page=80
# Scraping: https://www.pricebook.co.id/smartphone/?page=81
# Scraping: https://www.pricebook.co.id/smartphone/?page=82
# Scraping: https://www.pricebook.co.id/smartphone/?page=83
# Scraping: https://www.pricebook.co.id/smartphone/?page=84
# Scraping: https://www.pricebook.co.id/smartphone/?page=85
# Scraping: https://www.pricebook.co.id/smartphone/?page=86
# Scraping: https://www.pricebook.co.id/smartphone/?page=87
# Scraping: https://www.pricebook.co.id/smartphone/?page=88
# Scraping: https://www.pricebook.co.id/smartphone/?page=89
# Scraping: https://www.pricebook.co.id/smartphone/?page=90
# Scraping: https://www.pricebook.co.id/smartphone/?page=91
# Scraping: https://www.pricebook.co.id/smartphone/?page=92
# Scraping: https://www.pricebook.co.id/smartphone/?page=93
# Scraping: https://www.pricebook.co.id/smartphone/?page=94
# Scraping: https://www.pricebook.co.id/smartphone/?page=95
# Scraping: https://www.pricebook.co.id/smartphone/?page=96
# Scraping: https://www.pricebook.co.id/smartphone/?page=97
# Scraping: https://www.pricebook.co.id/smartphone/?page=98
# Scraping: https://www.pricebook.co.id/smartphone/?page=99
# Scraping: https://www.pricebook.co.id/smartphone/?page=100
# Scraping: https://www.pricebook.co.id/smartphone/?page=101
# Scraping: https://www.pricebook.co.id/smartphone/?page=102
# Scraping: https://www.pricebook.co.id/smartphone/?page=103
# Scraping: https://www.pricebook.co.id/smartphone/?page=104
# Scraping: https://www.pricebook.co.id/smartphone/?page=105
# Scraping: https://www.pricebook.co.id/smartphone/?page=106
# Scraping: https://www.pricebook.co.id/smartphone/?page=107
# Scraping: https://www.pricebook.co.id/smartphone/?page=108
# Scraping: https://www.pricebook.co.id/smartphone/?page=109
# Scraping: https://www.pricebook.co.id/smartphone/?page=110
# Scraping: https://www.pricebook.co.id/smartphone/?page=111
# Scraping: https://www.pricebook.co.id/smartphone/?page=112
# Scraping: https://www.pricebook.co.id/smartphone/?page=113
# Scraping: https://www.pricebook.co.id/smartphone/?page=114
# Scraping: https://www.pricebook.co.id/smartphone/?page=115
# Scraping: https://www.pricebook.co.id/smartphone/?page=116
# Scraping: https://www.pricebook.co.id/smartphone/?page=117
# Scraping: https://www.pricebook.co.id/smartphone/?page=118
# Scraping: https://www.pricebook.co.id/smartphone/?page=119
# Scraping: https://www.pricebook.co.id/smartphone/?page=120
# Scraping: https://www.pricebook.co.id/smartphone/?page=121
# Scraping: https://www.pricebook.co.id/smartphone/?page=122
# Scraping: https://www.pricebook.co.id/smartphone/?page=123
# Scraping: https://www.pricebook.co.id/smartphone/?page=124
# Scraping: https://www.pricebook.co.id/smartphone/?page=125
# Scraping: https://www.pricebook.co.id/smartphone/?page=126
# Scraping: https://www.pricebook.co.id/smartphone/?page=127
# Scraping: https://www.pricebook.co.id/smartphone/?page=128
# Scraping: https://www.pricebook.co.id/smartphone/?page=129
# Scraping: https://www.pricebook.co.id/smartphone/?page=130
# Scraping: https://www.pricebook.co.id/smartphone/?page=131
# Scraping: https://www.pricebook.co.id/smartphone/?page=132
# Scraping: https://www.pricebook.co.id/smartphone/?page=133
# Scraping: https://www.pricebook.co.id/smartphone/?page=134
# Scraping: https://www.pricebook.co.id/smartphone/?page=135
# Scraping: https://www.pricebook.co.id/smartphone/?page=136
# Scraping: https://www.pricebook.co.id/smartphone/?page=137
# Scraping: https://www.pricebook.co.id/smartphone/?page=138
# Scraping: https://www.pricebook.co.id/smartphone/?page=139
# Scraping: https://www.pricebook.co.id/smartphone/?page=140
# Scraping: https://www.pricebook.co.id/smartphone/?page=141
# Scraping: https://www.pricebook.co.id/smartphone/?page=142
# Scraping: https://www.pricebook.co.id/smartphone/?page=143
# Scraping: https://www.pricebook.co.id/smartphone/?page=144
# Scraping: https://www.pricebook.co.id/smartphone/?page=145
# Scraping: https://www.pricebook.co.id/smartphone/?page=146
# Scraping: https://www.pricebook.co.id/smartphone/?page=147
# Scraping: https://www.pricebook.co.id/smartphone/?page=148
# Scraping: https://www.pricebook.co.id/smartphone/?page=149
# Scraping: https://www.pricebook.co.id/smartphone/?page=150
# Scraping: https://www.pricebook.co.id/smartphone/?page=151
# Scraping: https://www.pricebook.co.id/smartphone/?page=152
# Scraping: https://www.pricebook.co.id/smartphone/?page=153
# Scraping: https://www.pricebook.co.id/smartphone/?page=154
# Scraping: https://www.pricebook.co.id/smartphone/?page=155
# Scraping: https://www.pricebook.co.id/smartphone/?page=156
# Scraping: https://www.pricebook.co.id/smartphone/?page=157
# Scraping: https://www.pricebook.co.id/smartphone/?page=158
# Scraping: https://www.pricebook.co.id/smartphone/?page=159
# Scraping: https://www.pricebook.co.id/smartphone/?page=160
# Scraping: https://www.pricebook.co.id/smartphone/?page=161
# Scraping: https://www.pricebook.co.id/smartphone/?page=162
# Scraping: https://www.pricebook.co.id/smartphone/?page=163
# Scraping: https://www.pricebook.co.id/smartphone/?page=164
# Scraping: https://www.pricebook.co.id/smartphone/?page=165
# Scraping: https://www.pricebook.co.id/smartphone/?page=166
# Scraping: https://www.pricebook.co.id/smartphone/?page=167
# Scraping: https://www.pricebook.co.id/smartphone/?page=168
# Scraping: https://www.pricebook.co.id/smartphone/?page=169
# Scraping: https://www.pricebook.co.id/smartphone/?page=170
# Scraping: https://www.pricebook.co.id/smartphone/?page=171
# Scraping: https://www.pricebook.co.id/smartphone/?page=172
# Scraping: https://www.pricebook.co.id/smartphone/?page=173
# Scraping: https://www.pricebook.co.id/smartphone/?page=174
# Scraping: https://www.pricebook.co.id/smartphone/?page=175
# Scraping: https://www.pricebook.co.id/smartphone/?page=176
# Scraping: https://www.pricebook.co.id/smartphone/?page=177
# Scraping: https://www.pricebook.co.id/smartphone/?page=178
# Scraping: https://www.pricebook.co.id/smartphone/?page=179
# Scraping: https://www.pricebook.co.id/smartphone/?page=180
# Scraping: https://www.pricebook.co.id/smartphone/?page=181
# Scraping: https://www.pricebook.co.id/smartphone/?page=182
# Scraping: https://www.pricebook.co.id/smartphone/?page=183
# Scraping: https://www.pricebook.co.id/smartphone/?page=184
# Scraping: https://www.pricebook.co.id/smartphone/?page=185
# Scraping: https://www.pricebook.co.id/smartphone/?page=186
# Scraping: https://www.pricebook.co.id/smartphone/?page=187
# Scraping: https://www.pricebook.co.id/smartphone/?page=188
# Scraping: https://www.pricebook.co.id/smartphone/?page=189
# Scraping: https://www.pricebook.co.id/smartphone/?page=190
# Scraping: https://www.pricebook.co.id/smartphone/?page=191
# Scraping: https://www.pricebook.co.id/smartphone/?page=192
# Scraping: https://www.pricebook.co.id/smartphone/?page=193
# Scraping: https://www.pricebook.co.id/smartphone/?page=194
# Scraping: https://www.pricebook.co.id/smartphone/?page=195
# Scraping: https://www.pricebook.co.id/smartphone/?page=196
# Scraping: https://www.pricebook.co.id/smartphone/?page=197
# Scraping: https://www.pricebook.co.id/smartphone/?page=198
# Scraping: https://www.pricebook.co.id/smartphone/?page=199
# Scraping: https://www.pricebook.co.id/smartphone/?page=200
# Scraping: https://www.pricebook.co.id/smartphone/?page=201
# Scraping: https://www.pricebook.co.id/smartphone/?page=202
# Scraping: https://www.pricebook.co.id/smartphone/?page=203
# Scraping: https://www.pricebook.co.id/smartphone/?page=204
# Scraping: https://www.pricebook.co.id/smartphone/?page=205
# Scraping: https://www.pricebook.co.id/smartphone/?page=206
# Scraping: https://www.pricebook.co.id/smartphone/?page=207
# Scraping: https://www.pricebook.co.id/smartphone/?page=208
# Scraping: https://www.pricebook.co.id/smartphone/?page=209
# Scraping: https://www.pricebook.co.id/smartphone/?page=210
# Scraping: https://www.pricebook.co.id/smartphone/?page=211
# Scraping: https://www.pricebook.co.id/smartphone/?page=212
# Scraping: https://www.pricebook.co.id/smartphone/?page=213
# Scraping: https://www.pricebook.co.id/smartphone/?page=214
# Scraping: https://www.pricebook.co.id/smartphone/?page=215
# Scraping: https://www.pricebook.co.id/smartphone/?page=216
# Scraping: https://www.pricebook.co.id/smartphone/?page=217
# Scraping: https://www.pricebook.co.id/smartphone/?page=218
# Scraping: https://www.pricebook.co.id/smartphone/?page=219
# Scraping: https://www.pricebook.co.id/smartphone/?page=220
# Scraping: https://www.pricebook.co.id/smartphone/?page=221
# Scraping: https://www.pricebook.co.id/smartphone/?page=222
# Scraping: https://www.pricebook.co.id/smartphone/?page=223
# Scraping: https://www.pricebook.co.id/smartphone/?page=224
# Scraping: https://www.pricebook.co.id/smartphone/?page=225
# Scraping: https://www.pricebook.co.id/smartphone/?page=226
# Scraping: https://www.pricebook.co.id/smartphone/?page=227
# Scraping: https://www.pricebook.co.id/smartphone/?page=228
# Scraping: https://www.pricebook.co.id/smartphone/?page=229
# Scraping: https://www.pricebook.co.id/smartphone/?page=230
# Scraping: https://www.pricebook.co.id/smartphone/?page=231
# Scraping: https://www.pricebook.co.id/smartphone/?page=232
# Scraping: https://www.pricebook.co.id/smartphone/?page=233
# Scraping: https://www.pricebook.co.id/smartphone/?page=234
# Scraping: https://www.pricebook.co.id/smartphone/?page=235
# Scraping: https://www.pricebook.co.id/smartphone/?page=236
# Scraping: https://www.pricebook.co.id/smartphone/?page=237
# Scraping: https://www.pricebook.co.id/smartphone/?page=238
# Scraping: https://www.pricebook.co.id/smartphone/?page=239
# Scraping: https://www.pricebook.co.id/smartphone/?page=240
# Scraping: https://www.pricebook.co.id/smartphone/?page=241
# Scraping: https://www.pricebook.co.id/smartphone/?page=242
# Scraping: https://www.pricebook.co.id/smartphone/?page=243
# Scraping: https://www.pricebook.co.id/smartphone/?page=244
# Scraping: https://www.pricebook.co.id/smartphone/?page=245
# Scraping: https://www.pricebook.co.id/smartphone/?page=246
# Scraping: https://www.pricebook.co.id/smartphone/?page=247
# Scraping: https://www.pricebook.co.id/smartphone/?page=248
# Scraping: https://www.pricebook.co.id/smartphone/?page=249
# Scraping: https://www.pricebook.co.id/smartphone/?page=250
# Scraping: https://www.pricebook.co.id/smartphone/?page=251
# Scraping: https://www.pricebook.co.id/smartphone/?page=252
# Scraping: https://www.pricebook.co.id/smartphone/?page=253
# Scraping: https://www.pricebook.co.id/smartphone/?page=254
# Scraping: https://www.pricebook.co.id/smartphone/?page=255
# Scraping: https://www.pricebook.co.id/smartphone/?page=256
# Scraping: https://www.pricebook.co.id/smartphone/?page=257
# Scraping: https://www.pricebook.co.id/smartphone/?page=258
# Scraping: https://www.pricebook.co.id/smartphone/?page=259
# Scraping: https://www.pricebook.co.id/smartphone/?page=260
# Scraping: https://www.pricebook.co.id/smartphone/?page=261
# Scraping: https://www.pricebook.co.id/smartphone/?page=262
# Scraping: https://www.pricebook.co.id/smartphone/?page=263
# Scraping: https://www.pricebook.co.id/smartphone/?page=264
# Scraping: https://www.pricebook.co.id/smartphone/?page=265
# Scraping: https://www.pricebook.co.id/smartphone/?page=266
# Scraping: https://www.pricebook.co.id/smartphone/?page=267
# Scraping: https://www.pricebook.co.id/smartphone/?page=268
# Scraping: https://www.pricebook.co.id/smartphone/?page=269
# Scraping: https://www.pricebook.co.id/smartphone/?page=270
# Scraping: https://www.pricebook.co.id/smartphone/?page=271
# Scraping: https://www.pricebook.co.id/smartphone/?page=272
# Scraping: https://www.pricebook.co.id/smartphone/?page=273
# Scraping: https://www.pricebook.co.id/smartphone/?page=274
# Scraping: https://www.pricebook.co.id/smartphone/?page=275
# Scraping: https://www.pricebook.co.id/smartphone/?page=276
# Scraping: https://www.pricebook.co.id/smartphone/?page=277
# Scraping: https://www.pricebook.co.id/smartphone/?page=278
# Scraping: https://www.pricebook.co.id/smartphone/?page=279
# Scraping: https://www.pricebook.co.id/smartphone/?page=280
# Scraping: https://www.pricebook.co.id/smartphone/?page=281
# Scraping: https://www.pricebook.co.id/smartphone/?page=282
# Scraping: https://www.pricebook.co.id/smartphone/?page=283
# Scraping: https://www.pricebook.co.id/smartphone/?page=284
# Scraping: https://www.pricebook.co.id/smartphone/?page=285
# Scraping: https://www.pricebook.co.id/smartphone/?page=286
# Scraping: https://www.pricebook.co.id/smartphone/?page=287
# Scraping: https://www.pricebook.co.id/smartphone/?page=288
# Scraping: https://www.pricebook.co.id/smartphone/?page=289
# Scraping: https://www.pricebook.co.id/smartphone/?page=290
# Scraping: https://www.pricebook.co.id/smartphone/?page=291
# Scraping: https://www.pricebook.co.id/smartphone/?page=292
# Scraping: https://www.pricebook.co.id/smartphone/?page=293
# Scraping: https://www.pricebook.co.id/smartphone/?page=294
# Scraping: https://www.pricebook.co.id/smartphone/?page=295
# Scraping: https://www.pricebook.co.id/smartphone/?page=296
# Scraping: https://www.pricebook.co.id/smartphone/?page=297
# Scraping: https://www.pricebook.co.id/smartphone/?page=298
# Scraping: https://www.pricebook.co.id/smartphone/?page=299
# Scraping: https://www.pricebook.co.id/smartphone/?page=300
# Scraping: https://www.pricebook.co.id/smartphone/?page=301
# Scraping: https://www.pricebook.co.id/smartphone/?page=302
# Scraping: https://www.pricebook.co.id/smartphone/?page=303
# Scraping: https://www.pricebook.co.id/smartphone/?page=304
# Scraping: https://www.pricebook.co.id/smartphone/?page=305
# Scraping: https://www.pricebook.co.id/smartphone/?page=306
# Scraping: https://www.pricebook.co.id/smartphone/?page=307
# Scraping: https://www.pricebook.co.id/smartphone/?page=308
# Scraping: https://www.pricebook.co.id/smartphone/?page=309
# Scraping: https://www.pricebook.co.id/smartphone/?page=310
# Scraping: https://www.pricebook.co.id/smartphone/?page=311
# Scraping: https://www.pricebook.co.id/smartphone/?page=312
# Scraping: https://www.pricebook.co.id/smartphone/?page=313
# Scraping: https://www.pricebook.co.id/smartphone/?page=314
# Scraping: https://www.pricebook.co.id/smartphone/?page=315
# Scraping: https://www.pricebook.co.id/smartphone/?page=316
# Scraping: https://www.pricebook.co.id/smartphone/?page=317
# Scraping: https://www.pricebook.co.id/smartphone/?page=318
# Scraping: https://www.pricebook.co.id/smartphone/?page=319
# Scraping: https://www.pricebook.co.id/smartphone/?page=320
# Scraping: https://www.pricebook.co.id/smartphone/?page=321
# Scraping: https://www.pricebook.co.id/smartphone/?page=322
# Scraping: https://www.pricebook.co.id/smartphone/?page=323
# Scraping: https://www.pricebook.co.id/smartphone/?page=324
# Scraping: https://www.pricebook.co.id/smartphone/?page=325
# Scraping: https://www.pricebook.co.id/smartphone/?page=326
# Scraping: https://www.pricebook.co.id/smartphone/?page=327
# Scraping: https://www.pricebook.co.id/smartphone/?page=328
# Scraping: https://www.pricebook.co.id/smartphone/?page=329
# Scraping: https://www.pricebook.co.id/smartphone/?page=330
# Scraping: https://www.pricebook.co.id/smartphone/?page=331
# Scraping: https://www.pricebook.co.id/smartphone/?page=332
# Scraping: https://www.pricebook.co.id/smartphone/?page=333
# Scraping: https://www.pricebook.co.id/smartphone/?page=334
# Scraping: https://www.pricebook.co.id/smartphone/?page=335
# Scraping: https://www.pricebook.co.id/smartphone/?page=336
# Scraping: https://www.pricebook.co.id/smartphone/?page=337
# Scraping: https://www.pricebook.co.id/smartphone/?page=338
# Scraping: https://www.pricebook.co.id/smartphone/?page=339
# Scraping: https://www.pricebook.co.id/smartphone/?page=340
# Scraping: https://www.pricebook.co.id/smartphone/?page=341
# Scraping: https://www.pricebook.co.id/smartphone/?page=342
# Scraping: https://www.pricebook.co.id/smartphone/?page=343
# Scraping: https://www.pricebook.co.id/smartphone/?page=344
# Scraping: https://www.pricebook.co.id/smartphone/?page=345
# Scraping: https://www.pricebook.co.id/smartphone/?page=346
# Scraping: https://www.pricebook.co.id/smartphone/?page=347
# Scraping: https://www.pricebook.co.id/smartphone/?page=348
# Scraping: https://www.pricebook.co.id/smartphone/?page=349
# Scraping: https://www.pricebook.co.id/smartphone/?page=350
# Scraping: https://www.pricebook.co.id/smartphone/?page=351
# Scraping: https://www.pricebook.co.id/smartphone/?page=352
# Scraping: https://www.pricebook.co.id/smartphone/?page=353
# Scraping: https://www.pricebook.co.id/smartphone/?page=354
# Scraping: https://www.pricebook.co.id/smartphone/?page=355
# Scraping: https://www.pricebook.co.id/smartphone/?page=356
# Scraping: https://www.pricebook.co.id/smartphone/?page=357
# Scraping: https://www.pricebook.co.id/smartphone/?page=358
# Scraping: https://www.pricebook.co.id/smartphone/?page=359
# Scraping: https://www.pricebook.co.id/smartphone/?page=360
# Scraping: https://www.pricebook.co.id/smartphone/?page=361
# Scraping: https://www.pricebook.co.id/smartphone/?page=362
# Scraping: https://www.pricebook.co.id/smartphone/?page=363
# Scraping: https://www.pricebook.co.id/smartphone/?page=364
# Scraping: https://www.pricebook.co.id/smartphone/?page=365
# Scraping: https://www.pricebook.co.id/smartphone/?page=366
# Scraping: https://www.pricebook.co.id/smartphone/?page=367
# Scraping: https://www.pricebook.co.id/smartphone/?page=368
# Scraping: https://www.pricebook.co.id/smartphone/?page=369
# Scraping: https://www.pricebook.co.id/smartphone/?page=370
# Scraping: https://www.pricebook.co.id/smartphone/?page=371
# Scraping: https://www.pricebook.co.id/smartphone/?page=372
# Scraping: https://www.pricebook.co.id/smartphone/?page=373
# Scraping: https://www.pricebook.co.id/smartphone/?page=374
# Scraping: https://www.pricebook.co.id/smartphone/?page=375
# Scraping: https://www.pricebook.co.id/smartphone/?page=376
# Scraping: https://www.pricebook.co.id/smartphone/?page=377
# Scraping: https://www.pricebook.co.id/smartphone/?page=378
# Scraping: https://www.pricebook.co.id/smartphone/?page=379
# Scraping: https://www.pricebook.co.id/smartphone/?page=380
# Scraping: https://www.pricebook.co.id/smartphone/?page=381
# Scraping: https://www.pricebook.co.id/smartphone/?page=382
# Scraping: https://www.pricebook.co.id/smartphone/?page=383
# Scraping: https://www.pricebook.co.id/smartphone/?page=384
# Scraping: https://www.pricebook.co.id/smartphone/?page=385
# Scraping: https://www.pricebook.co.id/smartphone/?page=386
# Scraping: https://www.pricebook.co.id/smartphone/?page=387
# Scraping: https://www.pricebook.co.id/smartphone/?page=388
# Scraping: https://www.pricebook.co.id/smartphone/?page=389
# Scraping: https://www.pricebook.co.id/smartphone/?page=390
# Scraping: https://www.pricebook.co.id/smartphone/?page=391
# Scraping: https://www.pricebook.co.id/smartphone/?page=392
# Scraping: https://www.pricebook.co.id/smartphone/?page=393
# Scraping: https://www.pricebook.co.id/smartphone/?page=394
# Scraping: https://www.pricebook.co.id/smartphone/?page=395
# Scraping: https://www.pricebook.co.id/smartphone/?page=396
# Scraping: https://www.pricebook.co.id/smartphone/?page=397
# Scraping: https://www.pricebook.co.id/smartphone/?page=398
# Scraping: https://www.pricebook.co.id/smartphone/?page=399
# Scraping: https://www.pricebook.co.id/smartphone/?page=400
# Scraping: https://www.pricebook.co.id/smartphone/?page=401
# Scraping: https://www.pricebook.co.id/smartphone/?page=402
# Scraping: https://www.pricebook.co.id/smartphone/?page=403
# Scraping: https://www.pricebook.co.id/smartphone/?page=404
# Scraping: https://www.pricebook.co.id/smartphone/?page=405
# Scraping: https://www.pricebook.co.id/smartphone/?page=406
# Scraping: https://www.pricebook.co.id/smartphone/?page=407
# Scraping: https://www.pricebook.co.id/smartphone/?page=408
# Scraping: https://www.pricebook.co.id/smartphone/?page=409
# Scraping: https://www.pricebook.co.id/smartphone/?page=410
# Scraping: https://www.pricebook.co.id/smartphone/?page=411
# Scraping: https://www.pricebook.co.id/smartphone/?page=412
# Scraping: https://www.pricebook.co.id/smartphone/?page=413
# Scraping: https://www.pricebook.co.id/smartphone/?page=414
# Scraping: https://www.pricebook.co.id/smartphone/?page=415
# Scraping: https://www.pricebook.co.id/smartphone/?page=416
# Scraping: https://www.pricebook.co.id/smartphone/?page=417
# Scraping: https://www.pricebook.co.id/smartphone/?page=418
# Scraping: https://www.pricebook.co.id/smartphone/?page=419
# Scraping: https://www.pricebook.co.id/smartphone/?page=420
# Scraping: https://www.pricebook.co.id/smartphone/?page=421
# Scraping: https://www.pricebook.co.id/smartphone/?page=422
# Scraping: https://www.pricebook.co.id/smartphone/?page=423
# Scraping: https://www.pricebook.co.id/smartphone/?page=424
# Scraping: https://www.pricebook.co.id/smartphone/?page=425
# Scraping: https://www.pricebook.co.id/smartphone/?page=426
# Scraping: https://www.pricebook.co.id/smartphone/?page=427
# Scraping: https://www.pricebook.co.id/smartphone/?page=428
# Scraping: https://www.pricebook.co.id/smartphone/?page=429
# Scraping: https://www.pricebook.co.id/smartphone/?page=430
# Scraping: https://www.pricebook.co.id/smartphone/?page=431
# Scraping: https://www.pricebook.co.id/smartphone/?page=432
# Scraping: https://www.pricebook.co.id/smartphone/?page=433
# Scraping: https://www.pricebook.co.id/smartphone/?page=434
# Scraping: https://www.pricebook.co.id/smartphone/?page=435
# Scraping: https://www.pricebook.co.id/smartphone/?page=436
# Scraping: https://www.pricebook.co.id/smartphone/?page=437
# Scraping: https://www.pricebook.co.id/smartphone/?page=438
# Scraping: https://www.pricebook.co.id/smartphone/?page=439
# Scraping: https://www.pricebook.co.id/smartphone/?page=440
# Scraping: https://www.pricebook.co.id/smartphone/?page=441
# Scraping: https://www.pricebook.co.id/smartphone/?page=442
# Scraping: https://www.pricebook.co.id/smartphone/?page=443
# Scraping: https://www.pricebook.co.id/smartphone/?page=444
# Scraping: https://www.pricebook.co.id/smartphone/?page=445
# Scraping: https://www.pricebook.co.id/smartphone/?page=446
# Scraping: https://www.pricebook.co.id/smartphone/?page=447
# Scraping: https://www.pricebook.co.id/smartphone/?page=448
# Scraping: https://www.pricebook.co.id/smartphone/?page=449
# Scraping: https://www.pricebook.co.id/smartphone/?page=450
# Scraping: https://www.pricebook.co.id/smartphone/?page=451
# Scraping: https://www.pricebook.co.id/smartphone/?page=452
# Scraping: https://www.pricebook.co.id/smartphone/?page=453
# Scraping: https://www.pricebook.co.id/smartphone/?page=454
# Scraping: https://www.pricebook.co.id/smartphone/?page=455
# Scraping: https://www.pricebook.co.id/smartphone/?page=456
# Scraping: https://www.pricebook.co.id/smartphone/?page=457
# Scraping: https://www.pricebook.co.id/smartphone/?page=458
# Scraping: https://www.pricebook.co.id/smartphone/?page=459
# Scraping: https://www.pricebook.co.id/smartphone/?page=460
# Scraping: https://www.pricebook.co.id/smartphone/?page=461
# Scraping: https://www.pricebook.co.id/smartphone/?page=462
# Scraping: https://www.pricebook.co.id/smartphone/?page=463
# Scraping: https://www.pricebook.co.id/smartphone/?page=464
# Scraping: https://www.pricebook.co.id/smartphone/?page=465
# Scraping: https://www.pricebook.co.id/smartphone/?page=466
# Scraping: https://www.pricebook.co.id/smartphone/?page=467
# Scraping: https://www.pricebook.co.id/smartphone/?page=468
# Scraping: https://www.pricebook.co.id/smartphone/?page=469
# Scraping: https://www.pricebook.co.id/smartphone/?page=470
# Scraping: https://www.pricebook.co.id/smartphone/?page=471
# Scraping: https://www.pricebook.co.id/smartphone/?page=472
# Scraping: https://www.pricebook.co.id/smartphone/?page=473
# Scraping: https://www.pricebook.co.id/smartphone/?page=474
# Scraping: https://www.pricebook.co.id/smartphone/?page=475
# Scraping: https://www.pricebook.co.id/smartphone/?page=476
# Scraping: https://www.pricebook.co.id/smartphone/?page=477
# Scraping: https://www.pricebook.co.id/smartphone/?page=478
# Scraping: https://www.pricebook.co.id/smartphone/?page=479
# Scraping: https://www.pricebook.co.id/smartphone/?page=480
# Scraping: https://www.pricebook.co.id/smartphone/?page=481
# Scraping: https://www.pricebook.co.id/smartphone/?page=482
# Scraping: https://www.pricebook.co.id/smartphone/?page=483
# Scraping: https://www.pricebook.co.id/smartphone/?page=484
# Scraping: https://www.pricebook.co.id/smartphone/?page=485
# Scraping: https://www.pricebook.co.id/smartphone/?page=486
# Scraping: https://www.pricebook.co.id/smartphone/?page=487
# Scraping: https://www.pricebook.co.id/smartphone/?page=488
# Scraping: https://www.pricebook.co.id/smartphone/?page=489
# Scraping: https://www.pricebook.co.id/smartphone/?page=490
# Scraping: https://www.pricebook.co.id/smartphone/?page=491
# Scraping: https://www.pricebook.co.id/smartphone/?page=492
# Scraping: https://www.pricebook.co.id/smartphone/?page=493
# Scraping: https://www.pricebook.co.id/smartphone/?page=494
# Scraping: https://www.pricebook.co.id/smartphone/?page=495
# Scraping: https://www.pricebook.co.id/smartphone/?page=496
# Scraping: https://www.pricebook.co.id/smartphone/?page=497
# Scraping: https://www.pricebook.co.id/smartphone/?page=498
# Scraping: https://www.pricebook.co.id/smartphone/?page=499
# Scraping: https://www.pricebook.co.id/smartphone/?page=500

# %% [markdown]
# Menampilkan hasil scrapping yang telah disimpan ke dalam file CSV

# %%
crawl = pd.DataFrame(crwl)
crawl.to_csv('pricebook_smartphone1.csv', encoding='utf-8', index=False)
crawl
# Out:
#         ID                                Product Name Product Rank     Ram  \
# 0        1                  OPPO A3s RAM 6GB ROM 128GB        #1 HP    6 GB
# 1        2        Infinix Hot 40 Pro RAM 8GB ROM 256GB        #2 HP    8 GB
# 2        3        Samsung Galaxy A15 RAM 8GB ROM 256GB        #3 HP    8 GB
# 3        4           OPPO A31 (2020) RAM 6GB ROM 128GB        #4 HP    6 GB
# 4        5          Xiaomi Redmi 13C RAM 8GB ROM 256GB        #5 HP    8 GB
# ...    ...                                         ...          ...     ...
# 5005  4996                         LG L20 D105 ROM 4GB     #5026 HP  512 MB
# 5006  4997  Smartfren Andromax G2 Touch QWERTY ROM 4GB     #5027 HP  512 MB
# 5007  4998                                   ZTE Kis 3     #5028 HP  256 MB
# 5008  4999     Mito Fantasy Selfie A77 RAM 1GB ROM 4GB     #5029 HP    1 GB
# 5009  5000                     Nokia Lumia 530 ROM 4GB     #5030 HP  512 MB
#
#        Camera     Screen   Battery         Price  Year  \
# 0       13 MP   6.2 inch  4230 mAh    Rp 532.000  2018
# 1      108 MP  6.78 inch  5000 mAh  Rp 1.704.000  2023
# 2       50 MP   6.5 inch  5000 mAh  Rp 2.719.000  2023
# 3       12 MP   6.5 inch  4230 mAh    Rp 950.000  2020
# 4       50 MP  6.74 inch  5000 mAh  Rp 1.599.000  2023
# ...       ...        ...       ...           ...   ...
# 5005     2 MP     3 inch  1540 mAh           N/A  2014
# 5006     5 MP   3.5 inch  1700 mAh           N/A  2014
# 5007  3.15 MP     4 inch  1400 mAh           N/A  2014
# 5008     8 MP   4.5 inch  1500 mAh           N/A  2014
# 5009     5 MP     4 inch  1430 mAh           N/A  2014
#
#                                             Product URL  \
# 0     https://www.pricebook.co.id/smartphone//OPPO-A...
# 1     https://www.pricebook.co.id/smartphone//Infini...
# 2     https://www.pricebook.co.id/smartphone//Samsun...
# 3     https://www.pricebook.co.id/smartphone//OPPO-A...
# 4     https://www.pricebook.co.id/smartphone//Xiaomi...
# ...                                                 ...
# 5005  https://www.pricebook.co.id/smartphone//LG-L20...
# 5006  https://www.pricebook.co.id/smartphone//Smartf...
# 5007  https://www.pricebook.co.id/smartphone//ZTE-Ki...
# 5008  https://www.pricebook.co.id/smartphone//Mito-F...
# 5009  https://www.pricebook.co.id/smartphone//Nokia-...
#
#                                           Product Image
# 0     https://cdn.pricebook.co.id/images/product/M/9...
# 1     https://cdn.pricebook.co.id/images/product/M/9...
# 2     https://cdn.pricebook.co.id/images/product/M/9...
# 3     https://cdn.pricebook.co.id/images/product/M/9...
# 4     https://cdn.pricebook.co.id/images/product/M/9...
# ...                                                 ...
# 5005  https://cdn.pricebook.co.id/images/product/M/2...
# 5006  https://cdn.pricebook.co.id/images/product/M/2...
# 5007  https://cdn.pricebook.co.id/images/product/M/2...
# 5008  https://cdn.pricebook.co.id/images/product/M/2...
# 5009  https://cdn.pricebook.co.id/images/product/M/2...
#
# [5010 rows x 11 columns]

# %% [markdown]
# # **Pre-Processing**

# %% [markdown]
# Kode ini bertujuan untuk membersihkan dan merapikan data mentah dari file pricebook_smartphone1.csv, agar siap digunakan untuk analisis atau dimasukkan ke database.

# %%
df = pd.read_csv('pricebook_smartphone1.csv')

# Bersihkan kolom harga (hapus Rp, titik, dll)
df['Price'] = df['Price'].apply(lambda x: re.sub(r'[^\d]', '', str(x)) if pd.notnull(x) else x)
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')

def extract_number(text):
    if pd.isnull(text):
        return None
    match = re.search(r'(\d+\.?\d*)', str(text))
    return float(match.group(1)) if match else None

# Mengubah tipe data
df['Ram (GB)'] = df['Ram'].apply(extract_number)
df['Camera (MP)'] = df['Camera'].apply(extract_number)
df['Screen (inch)'] = df['Screen'].apply(extract_number)
df['Battery (mAh)'] = df['Battery'].apply(extract_number)
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')

# Menghapus Kolom yang sudah tidak terpakai
df.drop_duplicates(subset=['Product Name'], inplace=True)
df.drop(columns=['Ram', 'Camera', 'Screen', 'Battery'], inplace=True)

df.to_csv('pricebook_products_clean1.csv', index=False)
df
# Out:
#         ID                                Product Name Product Rank  \
# 0        1                  OPPO A3s RAM 6GB ROM 128GB        #1 HP
# 1        2        Infinix Hot 40 Pro RAM 8GB ROM 256GB        #2 HP
# 2        3        Samsung Galaxy A15 RAM 8GB ROM 256GB        #3 HP
# 3        4           OPPO A31 (2020) RAM 6GB ROM 128GB        #4 HP
# 4        5          Xiaomi Redmi 13C RAM 8GB ROM 256GB        #5 HP
# ...    ...                                         ...          ...
# 5005  4996                         LG L20 D105 ROM 4GB     #5026 HP
# 5006  4997  Smartfren Andromax G2 Touch QWERTY ROM 4GB     #5027 HP
# 5007  4998                                   ZTE Kis 3     #5028 HP
# 5008  4999     Mito Fantasy Selfie A77 RAM 1GB ROM 4GB     #5029 HP
# 5009  5000                     Nokia Lumia 530 ROM 4GB     #5030 HP
#
#           Price    Year                                        Product URL  \
# 0      532000.0  2018.0  https://www.pricebook.co.id/smartphone//OPPO-A...
# 1     1704000.0  2023.0  https://www.pricebook.co.id/smartphone//Infini...
# 2     2719000.0  2023.0  https://www.pricebook.co.id/smartphone//Samsun...
# 3      950000.0  2020.0  https://www.pricebook.co.id/smartphone//OPPO-A...
# 4     1599000.0  2023.0  https://www.pricebook.co.id/smartphone//Xiaomi...
# ...         ...     ...                                                ...
# 5005        NaN  2014.0  https://www.pricebook.co.id/smartphone//LG-L20...
# 5006        NaN  2014.0  https://www.pricebook.co.id/smartphone//Smartf...
# 5007        NaN  2014.0  https://www.pricebook.co.id/smartphone//ZTE-Ki...
# 5008        NaN  2014.0  https://www.pricebook.co.id/smartphone//Mito-F...
# 5009        NaN  2014.0  https://www.pricebook.co.id/smartphone//Nokia-...
#
#                                           Product Image  Ram (GB)  \
# 0     https://cdn.pricebook.co.id/images/product/M/9...       6.0
# 1     https://cdn.pricebook.co.id/images/product/M/9...       8.0
# 2     https://cdn.pricebook.co.id/images/product/M/9...       8.0
# 3     https://cdn.pricebook.co.id/images/product/M/9...       6.0
# 4     https://cdn.pricebook.co.id/images/product/M/9...       8.0
# ...                                                 ...       ...
# 5005  https://cdn.pricebook.co.id/images/product/M/2...     512.0
# 5006  https://cdn.pricebook.co.id/images/product/M/2...     512.0
# 5007  https://cdn.pricebook.co.id/images/product/M/2...     256.0
# 5008  https://cdn.pricebook.co.id/images/product/M/2...       1.0
# 5009  https://cdn.pricebook.co.id/images/product/M/2...     512.0
#
#       Camera (MP)  Screen (inch)  Battery (mAh)
# 0           13.00           6.20         4230.0
# 1          108.00           6.78         5000.0
# 2           50.00           6.50         5000.0
# 3           12.00           6.50         4230.0
# 4           50.00           6.74         5000.0
# ...           ...            ...            ...
# 5005         2.00           3.00         1540.0
# 5006         5.00           3.50         1700.0
# 5007         3.15           4.00         1400.0
# 5008         8.00           4.50         1500.0
# 5009         5.00           4.00         1430.0
#
# [4866 rows x 11 columns]

# %% [markdown]
# ---

# %% [markdown]
# # **Sentence Transformer**

# %% [markdown]
# Di bagian ini adalah membangun sistem rekomendasi produk berbasis teks menggunakan model transformer. Pertama, setiap produk diubah menjadi deskripsi lengkap. Lalu, dengan bantuan model sentence-transformers, sistem membandingkan input pengguna dengan deskripsi tersebut menggunakan cosine similarity, dan akhirnya menampilkan lima smartphone yang paling relevan secara semantik.

# %%
from sentence_transformers import SentenceTransformer, util
import torch

# Load dataset
df = pd.read_csv('pricebook_products_clean1.csv')
selected_cols = ['Product Name', 'Price', 'Ram (GB)', 'Camera (MP)', 'Screen (inch)', 'Battery (mAh)']
df = df[selected_cols].dropna()

# Buat deskripsi produk
def create_description(row):
    return f"{row['Product Name']} dengan RAM {int(row['Ram (GB)'])}GB, kamera {int(row['Camera (MP)'])}MP, layar {row['Screen (inch)']} inci, baterai {int(row['Battery (mAh)'])}mAh, dan harga sekitar Rp{int(row['Price']):,}".replace(",", ".")

df['Product Description'] = df.apply(create_description, axis=1)

# Load model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Buat embedding produk
product_descriptions = df['Product Description'].tolist()
product_embeddings = model.encode(product_descriptions, convert_to_tensor=True)

# Input dari pengguna
query = input("Masukkan kebutuhan kamu (misal: 'HP kamera bagus dan baterai awet'): ")
query_embedding = model.encode(query, convert_to_tensor=True)

# Hitung cosine similarity
cos_scores = util.cos_sim(query_embedding, product_embeddings)[0]

# Ambil top 5
top_results = torch.topk(cos_scores, k=5)
top_indices = top_results.indices.tolist()
top_scores = top_results.values.tolist()

# Tampilkan hasil
print("\n📱 Rekomendasi Produk Berdasarkan Pencarian:")
for idx, score in zip(top_indices, top_scores):
    print(f"- {df.iloc[idx]['Product Name']} (Skor kemiripan: {score:.4f})")
    print(f"  {df.iloc[idx]['Product Description']}\n")
# Out:
# Masukkan kebutuhan kamu (misal: 'HP kamera bagus dan baterai awet'): hp dengan kapasitas ram besar
#
# 📱 Rekomendasi Produk Berdasarkan Pencarian:
# - Wiko Harry RAM 3GB ROM 16GB (Skor kemiripan: 0.6462)
#   Wiko Harry RAM 3GB ROM 16GB dengan RAM 3GB. kamera 13MP. layar 5.0 inci. baterai 2500mAh. dan harga sekitar Rp1.399.000
#
# - Lenovo K9 RAM 3GB ROM 32GB (Skor kemiripan: 0.6257)
#   Lenovo K9 RAM 3GB ROM 32GB dengan RAM 3GB. kamera 13MP. layar 5.7 inci. baterai 3000mAh. dan harga sekitar Rp1.850.000
#
# - itel P40 RAM 4GB ROM 64GB (Skor kemiripan: 0.6217)
#   itel P40 RAM 4GB ROM 64GB dengan RAM 4GB. kamera 13MP. layar 6.6 inci. baterai 6000mAh. dan harga sekitar Rp1.000.000
#
# - itel P40 RAM 4GB ROM 128GB (Skor kemiripan: 0.6213)
#   itel P40 RAM 4GB ROM 128GB dengan RAM 4GB. kamera 13MP. layar 6.6 inci. baterai 6000mAh. dan harga sekitar Rp1.199.000
#
# - OPPO K3 RAM 6GB ROM 64GB (Skor kemiripan: 0.6201)
#   OPPO K3 RAM 6GB ROM 64GB dengan RAM 6GB. kamera 16MP. layar 6.5 inci. baterai 3765mAh. dan harga sekitar Rp3.100.000

# %%
df = pd.read_csv('pricebook_products_clean1.csv')
df
# Out:
#         ID                                Product Name Product Rank  \
# 0        1                  OPPO A3s RAM 6GB ROM 128GB        #1 HP
# 1        2        Infinix Hot 40 Pro RAM 8GB ROM 256GB        #2 HP
# 2        3        Samsung Galaxy A15 RAM 8GB ROM 256GB        #3 HP
# 3        4           OPPO A31 (2020) RAM 6GB ROM 128GB        #4 HP
# 4        5          Xiaomi Redmi 13C RAM 8GB ROM 256GB        #5 HP
# ...    ...                                         ...          ...
# 4846  4996                         LG L20 D105 ROM 4GB     #5026 HP
# 4847  4997  Smartfren Andromax G2 Touch QWERTY ROM 4GB     #5027 HP
# 4848  4998                                   ZTE Kis 3     #5028 HP
# 4849  4999     Mito Fantasy Selfie A77 RAM 1GB ROM 4GB     #5029 HP
# 4850  5000                     Nokia Lumia 530 ROM 4GB     #5030 HP
#
#           Price    Year                                        Product URL  \
# 0      532000.0  2018.0  https://www.pricebook.co.id/smartphone//OPPO-A...
# 1     1704000.0  2023.0  https://www.pricebook.co.id/smartphone//Infini...
# 2     2719000.0  2023.0  https://www.pricebook.co.id/smartphone//Samsun...
# 3      950000.0  2020.0  https://www.pricebook.co.id/smartphone//OPPO-A...
# 4     1599000.0  2023.0  https://www.pricebook.co.id/smartphone//Xiaomi...
# ...         ...     ...                                                ...
# 4846        NaN  2014.0  https://www.pricebook.co.id/smartphone//LG-L20...
# 4847        NaN  2014.0  https://www.pricebook.co.id/smartphone//Smartf...
# 4848        NaN  2014.0  https://www.pricebook.co.id/smartphone//ZTE-Ki...
# 4849        NaN  2014.0  https://www.pricebook.co.id/smartphone//Mito-F...
# 4850        NaN  2014.0  https://www.pricebook.co.id/smartphone//Nokia-...
#
#                                           Product Image  Ram (GB)  \
# 0     https://cdn.pricebook.co.id/images/product/M/9...       6.0
# 1     https://cdn.pricebook.co.id/images/product/M/9...       8.0
# 2     https://cdn.pricebook.co.id/images/product/M/9...       8.0
# 3     https://cdn.pricebook.co.id/images/product/M/9...       6.0
# 4     https://cdn.pricebook.co.id/images/product/M/9...       8.0
# ...                                                 ...       ...
# 4846  https://cdn.pricebook.co.id/images/product/M/2...     512.0
# 4847  https://cdn.pricebook.co.id/images/product/M/2...     512.0
# 4848  https://cdn.pricebook.co.id/images/product/M/2...     256.0
# 4849  https://cdn.pricebook.co.id/images/product/M/2...       1.0
# 4850  https://cdn.pricebook.co.id/images/product/M/2...     512.0
#
#       Camera (MP)  Screen (inch)  Battery (mAh)
# 0           13.00           6.20         4230.0
# 1          108.00           6.78         5000.0
# 2           50.00           6.50         5000.0
# 3           12.00           6.50         4230.0
# 4           50.00           6.74         5000.0
# ...           ...            ...            ...
# 4846         2.00           3.00         1540.0
# 4847         5.00           3.50         1700.0
# 4848         3.15           4.00         1400.0
# 4849         8.00           4.50         1500.0
# 4850         5.00           4.00         1430.0
#
# [4851 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# ID                  0
# Product Name        0
# Product Rank        0
# Price            3091
# Year               43
# Product URL         0
# Product Image       0
# Ram (GB)          121
# Camera (MP)        42
# Screen (inch)      38
# Battery (mAh)     308
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# ID               0
# Product Name     0
# Product Rank     0
# Price            0
# Year             0
# Product URL      0
# Product Image    0
# Ram (GB)         0
# Camera (MP)      0
# Screen (inch)    0
# Battery (mAh)    0
# dtype: int64

# %%
df.to_csv('pricebook_products_clean1.csv', index=False)
df
# Out:
#         ID                           Product Name Product Rank      Price  \
# 0        1             OPPO A3s RAM 6GB ROM 128GB        #1 HP   532000.0
# 1        2   Infinix Hot 40 Pro RAM 8GB ROM 256GB        #2 HP  1704000.0
# 2        3   Samsung Galaxy A15 RAM 8GB ROM 256GB        #3 HP  2719000.0
# 3        4      OPPO A31 (2020) RAM 6GB ROM 128GB        #4 HP   950000.0
# 4        5     Xiaomi Redmi 13C RAM 8GB ROM 256GB        #5 HP  1599000.0
# ...    ...                                    ...          ...        ...
# 1870  1975       OUKITEL C17 Pro RAM 4GB ROM 64GB     #2005 HP  2518200.0
# 1872  1977  Infinix Note 7 Lite RAM 4GB ROM 128GB     #2007 HP  1849000.0
# 2634  2783           Realme 14T RAM 8GB ROM 256GB     #2813 HP  3599000.0
# 2671  2821           Realme 14T RAM 8GB ROM 128GB     #2851 HP  3199000.0
# 2683  2833         Realme 14 5G RAM 8GB ROM 256GB     #2863 HP  4199000.0
#
#         Year                                        Product URL  \
# 0     2018.0  https://www.pricebook.co.id/smartphone//OPPO-A...
# 1     2023.0  https://www.pricebook.co.id/smartphone//Infini...
# 2     2023.0  https://www.pricebook.co.id/smartphone//Samsun...
# 3     2020.0  https://www.pricebook.co.id/smartphone//OPPO-A...
# 4     2023.0  https://www.pricebook.co.id/smartphone//Xiaomi...
# ...      ...                                                ...
# 1870  2019.0  https://www.pricebook.co.id/smartphone//OUKITE...
# 1872  2020.0  https://www.pricebook.co.id/smartphone//Infini...
# 2634  2025.0  https://www.pricebook.co.id/smartphone//Realme...
# 2671  2025.0  https://www.pricebook.co.id/smartphone//Realme...
# 2683  2025.0  https://www.pricebook.co.id/smartphone//Realme...
#
#                                           Product Image  Ram (GB)  \
# 0     https://cdn.pricebook.co.id/images/product/M/9...       6.0
# 1     https://cdn.pricebook.co.id/images/product/M/9...       8.0
# 2     https://cdn.pricebook.co.id/images/product/M/9...       8.0
# 3     https://cdn.pricebook.co.id/images/product/M/9...       6.0
# 4     https://cdn.pricebook.co.id/images/product/M/9...       8.0
# ...                                                 ...       ...
# 1870  https://cdn.pricebook.co.id/images/product/M/9...       4.0
# 1872  https://cdn.pricebook.co.id/images/product/M/9...       4.0
# 2634  https://cdn.pricebook.co.id/images/product/M/1...       8.0
# 2671  https://cdn.pricebook.co.id/images/product/M/1...       8.0
# 2683  https://cdn.pricebook.co.id/images/product/M/1...       8.0
#
#       Camera (MP)  Screen (inch)  Battery (mAh)
# 0           13.00           6.20         4230.0
# 1          108.00           6.78         5000.0
# 2           50.00           6.50         5000.0
# 3           12.00           6.50         4230.0
# 4           50.00           6.74         5000.0
# ...           ...            ...            ...
# 1870        12.98           6.35         3900.0
# 1872        48.00           6.60         5000.0
# 2634        50.00           6.67         6000.0
# 2671        50.00           6.67         6000.0
# 2683        50.00           6.67         6000.0
#
# [1684 rows x 11 columns]
